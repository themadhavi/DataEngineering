# %%
# retails sales analysis data
import pandas as pd
import matplotlib.pyplot as plt

# %%
class RetailSalesAnalyzer:
  def __init__(self):
    self.data = pd.read_csv('retail_sales_dataset.csv')
    self.data['Date'] = pd.to_datetime(self.data['Date'])

  #check for null values and remove them
  def data_clean(self):
    self.data.dropna(inplace=True)

  def total_sales_per_product(self):
    return self.data.groupby('Product Category')['Price per Unit'].sum()

  def best_selling_product(self):
    return self.total_sales_per_product().sort_values(ascending=False).index[0]

  #compute avg daily sales
  def average_daily_sales(self):
    return self.data['Price per Unit'].mean()

  def plot_sales_trend(self):
    self.data.groupby('Date')['Price per Unit'].sum().plot(kind="line")
    plt.title('sales trend over Time')
    plt.xlabel('Date')
    plt.ylabel('Total Sales')
    plt.show()


  def plot_sales_per_product(self):
    self.total_sales_per_product().plot(kind='bar')
    plt.title("Sales Per Product")
    plt.xlabel('Product Category')
    plt.ylabel('Total Sales')
    plt.show()

# %%
analyzer = RetailSalesAnalyzer()
print('Total sales per product:', analyzer.total_sales_per_product())
print("Best selling product:", analyzer.best_selling_product())
print('Average Daily Sales ', analyzer.average_daily_sales())
# Out:
# Total sales per product: Product Category
# Beauty         56505
# Clothing       61175
# Electronics    62210
# Name: Price per Unit, dtype: int64
# Best selling product: Electronics
# Average Daily Sales  179.89

# %%
analyzer.plot_sales_per_product()
analyzer.plot_sales_trend()
